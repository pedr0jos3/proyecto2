# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("listings.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13043 entries, 0 to 13042
# Data columns (total 79 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            13043 non-null  int64
#  1   listing_url                                   13043 non-null  object
#  2   scrape_id                                     13043 non-null  int64
#  3   last_scraped                                  13043 non-null  object
#  4   source                                        13043 non-null  object
#  5   name                                          13043 non-null  object
#  6   description                                   12669 non-null  object
#  7   neighborhood_overview                         6929 non-null   object
#  8   picture_url                                   13043 non-null  object
#  9   host_id                                       13043 non-null  int64
#  10  host_url                                      13043 non-null  object
#  11  host_name                                     13043 non-null  object
#  12  host_since                                    13043 non-null  object
#  13  host_location                                 10558 non-null  object
#  14  host_about                                    7564 non-null   object
#  15  host_response_time                            11779 non-null  object
#  16  host_response_rate                            11779 non-null  object
#  17  host_acceptance_rate                          12365 non-null  object
#  18  host_is_superhost                             12102 non-null  object
#  19  host_thumbnail_url                            13043 non-null  object
#  20  host_picture_url                              13043 non-null  object
#  21  host_neighbourhood                            6239 non-null   object
#  22  host_listings_count                           13043 non-null  int64
#  23  host_total_listings_count                     13043 non-null  int64
#  24  host_verifications                            13043 non-null  object
#  25  host_has_profile_pic                          13043 non-null  object
#  26  host_identity_verified                        13043 non-null  object
#  27  neighbourhood                                 6929 non-null   object
#  28  neighbourhood_cleansed                        13043 non-null  object
#  29  neighbourhood_group_cleansed                  0 non-null      float64
#  30  latitude                                      13043 non-null  float64
#  31  longitude                                     13043 non-null  float64
#  32  property_type                                 13043 non-null  object
#  33  room_type                                     13043 non-null  object
#  34  accommodates                                  13043 non-null  int64
#  35  bathrooms                                     12025 non-null  float64
#  36  bathrooms_text                                13037 non-null  object
#  37  bedrooms                                      12918 non-null  float64
#  38  beds                                          11998 non-null  float64
#  39  amenities                                     13043 non-null  object
#  40  price                                         12026 non-null  object
#  41  minimum_nights                                13043 non-null  int64
#  42  maximum_nights                                13043 non-null  int64
#  43  minimum_minimum_nights                        13043 non-null  int64
#  44  maximum_minimum_nights                        13043 non-null  int64
#  45  minimum_maximum_nights                        13043 non-null  int64
#  46  maximum_maximum_nights                        13043 non-null  int64
#  47  minimum_nights_avg_ntm                        13043 non-null  float64
#  48  maximum_nights_avg_ntm                        13043 non-null  float64
#  49  calendar_updated                              0 non-null      float64
#  50  has_availability                              12978 non-null  object
#  51  availability_30                               13043 non-null  int64
#  52  availability_60                               13043 non-null  int64
#  53  availability_90                               13043 non-null  int64
#  54  availability_365                              13043 non-null  int64
#  55  calendar_last_scraped                         13043 non-null  object
#  56  number_of_reviews                             13043 non-null  int64
#  57  number_of_reviews_ltm                         13043 non-null  int64
#  58  number_of_reviews_l30d                        13043 non-null  int64
#  59  availability_eoy                              13043 non-null  int64
#  60  number_of_reviews_ly                          13043 non-null  int64
#  61  estimated_occupancy_l365d                     13043 non-null  int64
#  62  estimated_revenue_l365d                       12026 non-null  float64
#  63  first_review                                  11627 non-null  object
#  64  last_review                                   11627 non-null  object
#  65  review_scores_rating                          11627 non-null  float64
#  66  review_scores_accuracy                        11627 non-null  float64
#  67  review_scores_cleanliness                     11627 non-null  float64
#  68  review_scores_checkin                         11627 non-null  float64
#  69  review_scores_communication                   11627 non-null  float64
#  70  review_scores_location                        11627 non-null  float64
#  71  review_scores_value                           11627 non-null  float64
#  72  license                                       12297 non-null  object
#  73  instant_bookable                              13043 non-null  object
#  74  calculated_host_listings_count                13043 non-null  int64
#  75  calculated_host_listings_count_entire_homes   13043 non-null  int64
#  76  calculated_host_listings_count_private_rooms  13043 non-null  int64
#  77  calculated_host_listings_count_shared_rooms   13043 non-null  int64
#  78  reviews_per_month                             11627 non-null  float64
# dtypes: float64(18), int64(26), object(35)
# memory usage: 7.9+ MB

# %%
data.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  31840  https://www.airbnb.com/rooms/31840  20250619031413   2025-06-19
# 1  32180  https://www.airbnb.com/rooms/32180  20250619031413   2025-06-19
# 2  39115  https://www.airbnb.com/rooms/39115  20250619031413   2025-06-19
# 3  39165  https://www.airbnb.com/rooms/39165  20250619031413   2025-06-19
# 4  39822  https://www.airbnb.com/rooms/39822  20250619031413   2025-06-19
#
#             source                                      name  \
# 0      city scrape            Residenza Martin  Classic room
# 1      city scrape       Charming Gem - Oltrarno City centre
# 2  previous scrape            Central Double Shared Bathroom
# 3  previous scrape  Florence Central Double Private Bathroom
# 4      city scrape  Apartment Santa Monaca Oltrarno old town
#
#                                          description  \
# 0  Nice, private and quiet double room, classic s...
# 1                                                  .
# 2  Double Room Shared Bathroom: comfortable, larg...
# 3  Double room private bathroom: comfortable, lar...
# 4  Location details.<br />The bridge right next t...
#
#                                neighborhood_overview  \
# 0                                                NaN
# 1                                                NaN
# 2  San Lorenzo Church, the market and Cappelle Me...
# 3  San Lorenzo Church, the market and Cappelle Me...
# 4                                                NaN
#
#                                          picture_url   host_id  ...  \
# 0  https://a0.muscache.com/pictures/prohost-api/H...    380378  ...
# 1  https://a0.muscache.com/pictures/bcb23395-7215...  13925330  ...
# 2  https://a0.muscache.com/pictures/17793998/5f09...    167739  ...
# 3  https://a0.muscache.com/pictures/7e94f597-ac04...    167739  ...
# 4  https://a0.muscache.com/pictures/51118538/b6b9...    154769  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.91                   4.89                4.65
# 1                        4.70                   4.81                4.84
# 2                        4.74                   4.91                4.54
# 3                        4.64                   4.95                4.41
# 4                        4.71                   4.87                4.48
#
#               license instant_bookable calculated_host_listings_count  \
# 0  IT048017B4R5K5BW8E                t                             24
# 1  IT048017C232S8WUEN                f                              1
# 2  IT048017B9LED47MUB                f                             11
# 3  IT048017B9LED47MUB                f                             11
# 4  IT048017C2VVSRW6CW                f                              3
#
#   calculated_host_listings_count_entire_homes  \
# 0                                          14
# 1                                           1
# 2                                           3
# 3                                           3
# 4                                           3
#
#   calculated_host_listings_count_private_rooms  \
# 0                                           10
# 1                                            0
# 2                                            8
# 3                                            8
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              0.85
# 1                                           0              0.22
# 2                                           0              0.48
# 3                                           0              0.14
# 4                                           0              0.19
#
# [5 rows x 79 columns]

# %% [markdown]
# 1- Eliminamos las columnas con cero datos

# %%
columnas_vacias = data.columns[data.isnull().all()].tolist()
print(f"Columnas vacías encontradas: {columnas_vacias}")
data = data.drop(columns=columnas_vacias)
print(f"Eliminadas {len(columnas_vacias)} columnas vacías")
# Out:
# Columnas vacías encontradas: ['neighbourhood_group_cleansed', 'calendar_updated']
# Eliminadas 2 columnas vacías

# %% [markdown]
# 2- Convertimos los precios a numeros

# %%
def limpiar_precio(precio):
    if pd.isna(precio):
        return np.nan
    return float(str(precio).replace('$', '').replace(',', ''))
data['price'] = data['price'].apply(limpiar_precio)

print("Precios convertidos a números")
print(f"Precio más bajo: ${data['price'].min():.2f}")
print(f"Precio más alto: ${data['price'].max():.2f}")
print(f"Precio promedio: ${data['price'].mean():.2f}")
# Out:
# Precios convertidos a números
# Precio más bajo: $9.00
# Precio más alto: $18000.00
# Precio promedio: $263.78

# %% [markdown]
# 3- Convertimos los porcentajes a numeros

# %%
def limpiar_porcentaje(porcentaje):
    if pd.isna(porcentaje):
        return np.nan
    return float(str(porcentaje).replace('%', '')) / 100
data['host_response_rate'] = data['host_response_rate'].apply(limpiar_porcentaje)
data['host_acceptance_rate'] = data['host_acceptance_rate'].apply(limpiar_porcentaje)

print("Porcentajes convertidos a decimales (0 a 1)")
print(f"Tasa de respuesta promedio: {data['host_response_rate'].mean():.2%}")
print(f"Tasa de aceptación promedio: {data['host_acceptance_rate'].mean():.2%}")
# Out:
# Porcentajes convertidos a decimales (0 a 1)
# Tasa de respuesta promedio: 97.98%
# Tasa de aceptación promedio: 94.24%

# %% [markdown]
# 4- Convertimos columnas si/no a booleanas

# %%
columnas_bool = ['host_is_superhost',
    'host_has_profile_pic',
    'host_identity_verified',
    'has_availability',
    'instant_bookable']
for col in columnas_bool:
    if col in data.columns:
        data[col] = data[col].map({'t': True, 'f': False})
        print(f"{col} convertida")

print(f"\nSuperhosts: {data['host_is_superhost'].sum()} de {data['host_is_superhost'].notna().sum()}")
# Out:
# host_is_superhost convertida
# host_has_profile_pic convertida
# host_identity_verified convertida
# has_availability convertida
# instant_bookable convertida
#
# Superhosts: 5388 de 12102

# %% [markdown]
# 5- Convertimos fechas a un solo formato

# %%
columnas_fecha = ['last_scraped',
    'host_since',
    'calendar_last_scraped',
    'first_review',
    'last_review']


for col in columnas_fecha:
    if col in data.columns:
        data[col] = pd.to_datetime(data[col], errors='coerce')
        print(f"{col} convertida a fecha")

print(f"\nHost más antiguo: {data['host_since'].min()}")
print(f"Host más nuevo: {data['host_since'].max()}")
# Out:
# last_scraped convertida a fecha
# host_since convertida a fecha
# calendar_last_scraped convertida a fecha
# first_review convertida a fecha
# last_review convertida a fecha
#
# Host más antiguo: 2009-05-03 00:00:00
# Host más nuevo: 2025-06-16 00:00:00

# %% [markdown]
# 6- Juntar las columnas de datos que pueden estar juntas

# %%
review_columns = [col for col in data.columns if col.startswith('review_scores')]
data['review_scores'] = data[review_columns].mean(axis=1)

print("Nueva columna 'review_scores' creada con el promedio de las puntuaciones de revisión.")
print(data[['review_scores_rating', 'review_scores_accuracy','review_scores_cleanliness','review_scores_checkin','review_scores_communication', 'review_scores_location','review_scores_value','review_scores']].head())
# Out:
# Nueva columna 'review_scores' creada con el promedio de las puntuaciones de revisión.
#    review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 0                  4.67                    4.72                       4.85
# 1                  4.77                    4.81                       4.84
# 2                  4.52                    4.70                       4.60
# 3                  4.41                    4.32                       4.55
# 4                  4.48                    4.39                       4.45
#
#    review_scores_checkin  review_scores_communication  review_scores_location  \
# 0                   4.85                         4.91                    4.89
# 1                   4.78                         4.70                    4.81
# 2                   4.80                         4.74                    4.91
# 3                   4.73                         4.64                    4.95
# 4                   4.71                         4.71                    4.87
#
#    review_scores_value  review_scores
# 0                 4.65       4.791429
# 1                 4.84       4.792857
# 2                 4.54       4.687143
# 3                 4.41       4.572857
# 4                 4.48       4.584286

# %% [markdown]
# 7- Eliminamos columnas innecesarias

# %%
columnas_eliminar = [
    'listing_url',
    'scrape_id',
    'host_url',
    'host_thumbnail_url',
    'host_picture_url',
    'picture_url',
    'host_neighbourhood',
    'source',
    'host_verifications',
    'amenities',
    'host_about',
    'description',
    'neighborhood_overview',"minimum_minimum_nights",
    "maximum_minimum_nights",
    "minimum_maximum_nights", "maximum_maximum_nights",
    "minimum_nights_avg_ntm","maximum_nights_avg_ntm","bathrooms","host_location",
    "host_listings_count", 'review_scores_rating',
    'review_scores_accuracy','review_scores_cleanliness','review_scores_checkin',
    'review_scores_communication', 'review_scores_location',"review_scores_value"]

columnas_eliminadas = [col for col in columnas_eliminar if col in data.columns]
data = data.drop(columns=columnas_eliminadas)

print(f"Eliminadas {len(columnas_eliminadas)} columnas innecesarias")
print(f"Columnas restantes: {data.shape[1]}")
# Out:
# Eliminadas 29 columnas innecesarias
# Columnas restantes: 49

# %% [markdown]
# 8- Eliminamos los duplicados

# %%
duplicados = data.duplicated().sum()

if duplicados > 0:
    data = data.drop_duplicates()
    print(f"Eliminados {duplicados} registros duplicados")
else:
    print("No hay duplicados")
# Out:
# No hay duplicados

# %% [markdown]
# 9- Eliminamos propieades inactivas

# %%
data['days_since_last_review'] = (pd.Timestamp.now() - data['last_review']).dt.days

antes = len(data)

data = data[(data['days_since_last_review'].isna()) | (data['days_since_last_review'] <= 730)]

eliminados = antes - len(data)
print(f"Eliminadas {eliminados} propiedades inactivas (sin reviews en 2+ años)")
# Out:
# Eliminadas 994 propiedades inactivas (sin reviews en 2+ años)

# %% [markdown]
# 10- Eliminamos las propiedades sin precio

# %%
antes = len(data)
data = data[data['price'].notna()]

eliminados = antes - len(data)
print(f"Eliminadas {eliminados} propiedades sin precio")
# Out:
# Eliminadas 843 propiedades sin precio

# %% [markdown]
# 11- Eliminamos datos inconsistentes

# %%
antes = len(data)
data = data[(data['beds'].isna()) | (data['bedrooms'].isna()) | (data['beds'] >= data['bedrooms'])]

eliminados = antes - len(data)
print(f"Eliminadas {eliminados} propiedades inconsistentes (más habitaciones que camas)")
# Out:
# Eliminadas 205 propiedades inconsistentes (más habitaciones que camas)

# %% [markdown]
# 12- Eliminamos precios anómalos

# %%
antes = len(data)


data = data[(data['price'].isna()) | ((data['price'] >= 20) & (data['price'] <= 10000))]

eliminados = antes - len(data)
print(f"Eliminadas {eliminados} propiedades con precios anómalos")
print(f"Nuevo rango de precios: ${data['price'].min():.2f} - ${data['price'].max():.2f}")
# Out:
# Eliminadas 18 propiedades con precios anómalos
# Nuevo rango de precios: $20.00 - $10000.00

# %% [markdown]
# 13- Llenar los datos faltantes

# %%
data['neighbourhood'].fillna("Florence,Tuscany,Italy", inplace = True)
data['host_response_time'].replace(np.nan, 'Sin registro', inplace = True)
data['host_response_rate'].replace(np.nan, 'Sin registro', inplace = True)
data['host_acceptance_rate'].replace(np.nan, 'Sin registro', inplace = True)
data['host_is_superhost'].replace(np.nan, 'Sin registro', inplace = True)
data['beds'].replace(np.nan, 0, inplace = True)
data['bedrooms'].replace(np.nan, 0, inplace = True)
data['bathrooms_text'].replace(np.nan, 'Sin registro', inplace = True)
data['has_availability'].replace(np.nan, 'Sin registro', inplace = True)
data['first_review'].replace(np.nan, 'Sin registro', inplace = True)
data['last_review'].replace(np.nan, 'Sin registro', inplace = True)
data['license'].replace(np.nan, 'Sin registro', inplace = True)
data['reviews_per_month'].replace(np.nan, 0, inplace = True)
data['days_since_last_review'].replace(np.nan, 'Sin registro', inplace = True)
data['review_scores'].replace(np.nan, 0, inplace = True)
# Out:
# C:\Users\peter\AppData\Local\Temp\ipykernel_16252\698305778.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['neighbourhood'].fillna("Florence,Tuscany,Italy", inplace = True)
# C:\Users\peter\AppData\Local\Temp\ipykernel_16252\698305778.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['host_response_time'].replace(np.nan, 'Sin registro', inplace = True)
# C:\Users\peter\AppData\Local\Temp\ipykernel_16252\698305778.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['host_response_rate'].replace(np.nan, 'Sin registro', inplace = True)
# C:\Users\peter\AppData\Local\Temp\ipykernel_16252\698305778.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['host_acceptance_rate'].replace(np.nan, 'Sin registro', inplace = True)
# C:\Users\peter\AppData\Local\Temp\ipykernel_16252\698305778.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['host_is_superhost'].replace(np.nan, 'Sin registro', inplace = True)
# C:\Users\peter\AppData\Local\Temp\ipykernel_16252\698305778.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['beds'].replace(np.nan, 0, inplace = True)
# C:\Users\peter\AppData\Local\Temp\ipykernel_16252\698305778.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['bedrooms'].replace(np.nan, 0, inplace = True)
# C:\Users\peter\AppData\Local\Temp\ipykernel_16252\698305778.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['bathrooms_text'].replace(np.nan, 'Sin registro', inplace = True)
# C:\Users\peter\AppData\Local\Temp\ipykernel_16252\698305778.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['has_availability'].replace(np.nan, 'Sin registro', inplace = True)
# C:\Users\peter\AppData\Local\Temp\ipykernel_16252\698305778.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['first_review'].replace(np.nan, 'Sin registro', inplace = True)
# C:\Users\peter\AppData\Local\Temp\ipykernel_16252\698305778.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['last_review'].replace(np.nan, 'Sin registro', inplace = True)
# C:\Users\peter\AppData\Local\Temp\ipykernel_16252\698305778.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['license'].replace(np.nan, 'Sin registro', inplace = True)
# C:\Users\peter\AppData\Local\Temp\ipykernel_16252\698305778.py:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['reviews_per_month'].replace(np.nan, 0, inplace = True)
# C:\Users\peter\AppData\Local\Temp\ipykernel_16252\698305778.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['days_since_last_review'].replace(np.nan, 'Sin registro', inplace = True)
# C:\Users\peter\AppData\Local\Temp\ipykernel_16252\698305778.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['review_scores'].replace(np.nan, 0, inplace = True)

# %%
data.isnull().sum()
# Out:
# id                                              0
# last_scraped                                    0
# name                                            0
# host_id                                         0
# host_name                                       0
# host_since                                      0
# host_response_time                              0
# host_response_rate                              0
# host_acceptance_rate                            0
# host_is_superhost                               0
# host_total_listings_count                       0
# host_has_profile_pic                            0
# host_identity_verified                          0
# neighbourhood                                   0
# neighbourhood_cleansed                          0
# latitude                                        0
# longitude                                       0
# property_type                                   0
# room_type                                       0
# accommodates                                    0
# bathrooms_text                                  0
# bedrooms                                        0
# beds                                            0
# price                                           0
# minimum_nights                                  0
# maximum_nights                                  0
# has_availability                                0
# availability_30                                 0
# availability_60                                 0
# availability_90                                 0
# availability_365                                0
# calendar_last_scraped                           0
# number_of_reviews                               0
# number_of_reviews_ltm                           0
# number_of_reviews_l30d                          0
# availability_eoy                                0
# number_of_reviews_ly                            0
# estimated_occupancy_l365d                       0
# estimated_revenue_l365d                         0
# first_review                                    0
# last_review                                     0
# license                                         0
# instant_bookable                                0
# calculated_host_listings_count                  0
# calculated_host_listings_count_entire_homes     0
# calculated_host_listings_count_private_rooms    0
# calculated_host_listings_count_shared_rooms     0
# reviews_per_month                               0
# review_scores                                   0
# days_since_last_review                          0
# dtype: int64

# %% [markdown]
# 14- Crear columnas nuevas que simplifiquen

# %%
print("Creando nuevas columnas...\n")

# 1. Precio por persona
data['price_per_person'] = data['price'] / data['accommodates']
print("price_per_person: precio dividido entre capacidad")

# 4. Categoría de precio
data['price_category'] = pd.cut(
    data['price'],
    bins=[0, 50, 100, 200, 500, 10000],
    labels=['Muy Barato', 'Económico', 'Medio', 'Caro', 'Lujo']
)
print("price_category: clasificación de precio")

# 5. Tipo de propiedad simplificado
def simplificar_tipo(tipo):
    tipo = str(tipo).lower()
    if 'apartment' in tipo or 'rental unit' in tipo or 'condo' in tipo:
        return 'Apartment'
    elif 'house' in tipo or 'home' in tipo or 'villa' in tipo:
        return 'House'
    elif 'hotel' in tipo:
        return 'Hotel'
    elif 'bed and breakfast' in tipo or 'bnb' in tipo:
        return 'B&B'
    elif 'loft' in tipo:
        return 'Loft'
    else:
        return 'Other'

data['property_type_simple'] = data['property_type'].apply(simplificar_tipo)
print("property_type_simple: tipo de propiedad simplificado")


# 8. Tasa de ocupación
data['occupancy_rate'] = data['estimated_occupancy_l365d'] / 365
print("occupancy_rate: porcentaje de días ocupados")

# 9. Si es propiedad completa
data['is_entire_place'] = data['room_type'] == 'Entire home/apt'
print("is_entire_place: si es departamento/casa completa")

# 10. Categoría por capacidad
data['capacity_category'] = pd.cut(
    data['accommodates'],
    bins=[0, 2, 4, 6, 20],
    labels=['Pareja', 'Pequeño', 'Mediano', 'Grande']
)
print("capacity_category: clasificación por capacidad")



print(f"\n{12} nuevas columnas creadas")
# Out:
# Creando nuevas columnas...
#
# price_per_person: precio dividido entre capacidad
# price_category: clasificación de precio
# property_type_simple: tipo de propiedad simplificado
# occupancy_rate: porcentaje de días ocupados
# is_entire_place: si es departamento/casa completa
# capacity_category: clasificación por capacidad
#
# 12 nuevas columnas creadas

# %% [markdown]
# 15- Eliminar las columnas que ya no sirven

# %%
columnas_viejas = ['property_type','estimated_occupancy_l365d','room_type']

columnas_viejas = [col for col in columnas_viejas if col in data.columns]
data = data.drop(columns=columnas_viejas)

print(f"Eliminadas {len(columnas_viejas)} columnas innecesarias")
print(f"Columnas restantes: {data.shape[1]}")
# Out:
# Eliminadas 3 columnas innecesarias
# Columnas restantes: 53

# %%
data.info()
data.to_csv("listings_cleaned.csv", index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10983 entries, 0 to 13042
# Data columns (total 53 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            10983 non-null  int64
#  1   last_scraped                                  10983 non-null  datetime64[ns]
#  2   name                                          10983 non-null  object
#  3   host_id                                       10983 non-null  int64
#  4   host_name                                     10983 non-null  object
#  5   host_since                                    10983 non-null  datetime64[ns]
#  6   host_response_time                            10983 non-null  object
#  7   host_response_rate                            10983 non-null  object
#  8   host_acceptance_rate                          10983 non-null  object
#  9   host_is_superhost                             10983 non-null  object
#  10  host_total_listings_count                     10983 non-null  int64
#  11  host_has_profile_pic                          10983 non-null  bool
#  12  host_identity_verified                        10983 non-null  bool
#  13  neighbourhood                                 10983 non-null  object
#  14  neighbourhood_cleansed                        10983 non-null  object
#  15  latitude                                      10983 non-null  float64
#  16  longitude                                     10983 non-null  float64
#  17  accommodates                                  10983 non-null  int64
#  18  bathrooms_text                                10983 non-null  object
#  19  bedrooms                                      10983 non-null  float64
#  20  beds                                          10983 non-null  float64
#  21  price                                         10983 non-null  float64
#  22  minimum_nights                                10983 non-null  int64
#  23  maximum_nights                                10983 non-null  int64
#  24  has_availability                              10983 non-null  object
#  25  availability_30                               10983 non-null  int64
#  26  availability_60                               10983 non-null  int64
#  27  availability_90                               10983 non-null  int64
#  28  availability_365                              10983 non-null  int64
#  29  calendar_last_scraped                         10983 non-null  datetime64[ns]
#  30  number_of_reviews                             10983 non-null  int64
#  31  number_of_reviews_ltm                         10983 non-null  int64
#  32  number_of_reviews_l30d                        10983 non-null  int64
#  33  availability_eoy                              10983 non-null  int64
#  34  number_of_reviews_ly                          10983 non-null  int64
#  35  estimated_revenue_l365d                       10983 non-null  float64
#  36  first_review                                  10983 non-null  object
#  37  last_review                                   10983 non-null  object
#  38  license                                       10983 non-null  object
#  39  instant_bookable                              10983 non-null  bool
#  40  calculated_host_listings_count                10983 non-null  int64
#  41  calculated_host_listings_count_entire_homes   10983 non-null  int64
#  42  calculated_host_listings_count_private_rooms  10983 non-null  int64
#  43  calculated_host_listings_count_shared_rooms   10983 non-null  int64
#  44  reviews_per_month                             10983 non-null  float64
#  45  review_scores                                 10983 non-null  float64
#  46  days_since_last_review                        10983 non-null  object
#  47  price_per_person                              10983 non-null  float64
#  48  price_category                                10983 non-null  category
#  49  property_type_simple                          10983 non-null  object
#  50  occupancy_rate                                10983 non-null  float64
#  51  is_entire_place                               10983 non-null  bool
#  52  capacity_category                             10983 non-null  category
# dtypes: bool(4), category(2), datetime64[ns](3), float64(10), int64(19), object(15)
# memory usage: 4.1+ MB
